# %% [markdown]
# # Rohit Sharma Career Data Transformation

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Data Preparation and Transformation

# %% [markdown]
# ### Importing files as dataframes

# %%
match_awards = pd.read_csv("../output/csv/match_awards.csv")
match_results = pd.read_csv("""../output/csv/match_results.csv""")
scores = pd.read_csv("""../output/csv/scores.csv""")

# %% [markdown]
# ### Scores Data Analysis

# %%
scores.describe()
# Out:
#         Runs  Mins    BF    4s    6s    SR   Pos Dismissal  Inns   Opposition  \
# count   1014  1014  1014  1014  1014  1014  1014      1014  1014         1014
# unique   189   163   137    24    14   457     9         8     5           54
# top        0     -     2     0     0  0.00     1    caught     2  v Australia
# freq      65   221    39   236   492    66   435       582   480          120
#
#           Ground   Start Date  match_id
# count       1014         1014      1014
# unique        89          803       500
# top     Wankhede  29 Jun 2024  Twenty20
# freq         105            2       304

# %% [markdown]
# ### Scores Data Cleaning

# %% [markdown]
# #### Removing unncessary columns - "Mins"

# %%
scores = scores.drop(['Mins'],axis=1).copy()

# %% [markdown]
# #### Drop duplicate Rows

# %%
scores[scores.duplicated()]
# Out:
#     Runs  BF 4s 6s      SR Pos Dismissal Inns      Opposition        Ground  \
# 559  DNB   -  -  -       -   -         -    1       v England        Durban
# 560  50*  40  7  2  125.00   5   not out    1  v South Africa        Durban
# 561   8*   5  0  1  160.00   6   not out    1     v Australia        Durban
# 562  30*  16  2  1  187.50   6   not out    1      v Pakistan  Johannesburg
# 563  DNB   -  -  -       -   -         -    2     v Australia     Brabourne
# ..   ...  .. .. ..     ...  ..       ...  ...             ...           ...
# 994    8  13  1  0   61.53   1    caught    1   v Afghanistan    Bridgetown
# 995   23  11  3  1  209.09   1    caught    1    v Bangladesh   North Sound
# 996   92  41  7  8  224.39   1    bowled    1     v Australia    Gros Islet
# 997   57  39  6  2  146.15   1    bowled    1       v England    Providence
# 998    9   5  2  0  180.00   1    caught    1  v South Africa    Bridgetown
#
#       Start Date     match_id
# 559  19 Sep 2007    T20I # 40
# 560  20 Sep 2007    T20I # 43
# 561  22 Sep 2007    T20I # 45
# 562  24 Sep 2007    T20I # 46
# 563  20 Oct 2007    T20I # 47
# ..           ...          ...
# 994  20 Jun 2024  T20I # 2710
# 995  22 Jun 2024  T20I # 2716
# 996  24 Jun 2024  T20I # 2721
# 997  27 Jun 2024  T20I # 2724
# 998  29 Jun 2024  T20I # 2729
#
# [159 rows x 12 columns]

# %%
scores[scores["match_id"] == "T20I # 45"]
# Out:
#     Runs BF 4s 6s      SR Pos Dismissal Inns   Opposition  Ground  \
# 394   8*  5  0  1  160.00   6   not out    1  v Australia  Durban
# 561   8*  5  0  1  160.00   6   not out    1  v Australia  Durban
#
#       Start Date   match_id
# 394  22 Sep 2007  T20I # 45
# 561  22 Sep 2007  T20I # 45

# %%
scores.drop_duplicates(inplace=True)
scores
# Out:
#       Runs   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0      177  301  23  1   58.80   6       lbw    2   v West Indies
# 1     111*  127  11  3   87.40   6   not out    2   v West Indies
# 2       14   42   1  0   33.33   5    caught    1  v South Africa
# 3        6   13   1  0   46.15   5    bowled    3  v South Africa
# 4        0    1   0  0    0.00   5    bowled    1  v South Africa
# ...    ...  ...  .. ..     ...  ..       ...  ...             ...
# 1009     7    8   1  0   87.50   2    caught    1            v GT
# 1010     5    5   1  0  100.00   2    caught    1            v DC
# 1011    24   21   2  1  114.28   2    caught    1  v Punjab Kings
# 1012    81   50   9  4  162.00   1    caught    1            v GT
# 1013     8    7   1  0  114.28   1    caught    1  v Punjab Kings
#
#               Ground   Start Date     match_id
# 0       Eden Gardens   6 Nov 2013  Test # 2101
# 1           Wankhede  14 Nov 2013  Test # 2102
# 2       Johannesburg  18 Dec 2013  Test # 2108
# 3       Johannesburg  18 Dec 2013  Test # 2108
# 4             Durban  26 Dec 2013  Test # 2111
# ...              ...          ...          ...
# 1009        Wankhede   6 May 2025     Twenty20
# 1010        Wankhede  21 May 2025     Twenty20
# 1011          Jaipur  26 May 2025     Twenty20
# 1012  New Chandigarh  30 May 2025     Twenty20
# 1013       Ahmedabad   1 Jun 2025     Twenty20
#
# [855 rows x 12 columns]

# %% [markdown]
# #### Remove matches where he did not play

# %%
scores[((scores["Runs"] == "DNB") | (scores["Runs"] == "TDNB"))]
# Out:
#      Runs BF 4s 6s SR Pos Dismissal Inns      Opposition         Ground  \
# 31   TDNB  -  -  -  -   -         -    -   v West Indies  Port of Spain
# 37    DNB  -  -  -  -   -         -    3   v New Zealand         Indore
# 116   DNB  -  -  -  -   -         -    4     v Australia       Brisbane
# 119   DNB  -  -  -  -   -         -    2       v Ireland        Belfast
# 154   DNB  -  -  -  -   -         -    2   v New Zealand       Hamilton
# 159  TDNB  -  -  -  -   -         -    -   v West Indies     Gros Islet
# 174   DNB  -  -  -  -   -         -    2   v New Zealand        Chennai
# 196   DNB  -  -  -  -   -         -    1     v Sri Lanka         Mirpur
# 232  TDNB  -  -  -  -   -         -    -  v South Africa      Centurion
# 334  TDNB  -  -  -  -   -         -    -   v West Indies     Providence
# 368   DNB  -  -  -  -   -         -    2     v Sri Lanka  Colombo (RPS)
# 392   DNB  -  -  -  -   -         -    1       v England         Durban
# 396   DNB  -  -  -  -   -         -    2     v Australia      Brabourne
# 408   DNB  -  -  -  -   -         -    1     v Sri Lanka     Gros Islet
# 415   DNB  -  -  -  -   -         -    2     v Australia      Melbourne
# 416   DNB  -  -  -  -   -         -    2  v South Africa   Johannesburg
# 417   DNB  -  -  -  -   -         -    1     v Sri Lanka      Pallekele
# 422   DNB  -  -  -  -   -         -    2      v Pakistan  Colombo (RPS)
# 480  TDNB  -  -  -  -   -         -    -     v Australia      Melbourne
# 568   DNB  -  -  -  -   -         -    2            v MI       DY Patil
# 632   DNB  -  -  -  -   -         -    2           v RCB      Bengaluru
# 633   DNB  -  -  -  -   -         -    1         v Kochi       Wankhede
# 673   DNB  -  -  -  -   -         -    2            v RR         Jaipur
# 792   DNB  -  -  -  -   -         -    2      v Kings XI         Indore
#
#       Start Date     match_id
# 31   18 Aug 2016  Test # 2218
# 37    8 Oct 2016  Test # 2223
# 116  14 Dec 2024  Test # 2570
# 119  23 Jun 2007   ODI # 2590
# 154  11 Mar 2009   ODI # 2824
# 159   5 Jul 2009   ODI # 2855
# 174  10 Dec 2010   ODI # 3077
# 196  13 Mar 2012   ODI # 3259
# 232  11 Dec 2013   ODI # 3444
# 334   8 Aug 2019   ODI # 4196
# 368  17 Sep 2023   ODI # 4649
# 392  19 Sep 2007    T20I # 40
# 396  20 Oct 2007    T20I # 47
# 408  11 May 2010   T20I # 173
# 415   3 Feb 2012   T20I # 218
# 416  30 Mar 2012   T20I # 242
# 417   7 Aug 2012   T20I # 255
# 422  30 Sep 2012   T20I # 282
# 480  23 Nov 2018   T20I # 713
# 568  27 Apr 2008     Twenty20
# 632  12 Apr 2011     Twenty20
# 633  15 Apr 2011     Twenty20
# 673  20 May 2012     Twenty20
# 792  20 Apr 2017     Twenty20

# %%
scores = scores[~((scores['Runs']=='DNB')|(scores['Runs']=='TDNB'))]
scores.shape
# Out:
# (831, 12)

# %% [markdown]
# #### Remove '*' from Runs

# %%
scores[scores['Runs'].str.endswith('*')]
# Out:
#       Runs   BF  4s 6s      SR Pos Dismissal Inns     Opposition      Ground  \
# 1     111*  127  11  3   87.40   6   not out    2  v West Indies    Wankhede
# 9      31*   97   4  0   31.95   5   not out    4  v New Zealand  Wellington
# 33     68*   93   8  0   73.11   6   not out    3  v New Zealand      Kanpur
# 36     51*   63   3  2   80.95   6   not out    1  v New Zealand      Indore
# 38    102*  160   8  1   63.75   6   not out    2    v Sri Lanka      Nagpur
# ...    ...  ...  .. ..     ...  ..       ...  ...            ...         ...
# 827    56*   33   6  2  169.69   3   not out    2          v CSK        Pune
# 829    24*   15   1  2  160.00   5   not out    2     v Kings XI      Indore
# 862    55*   48   8  0  114.58   2   not out    2          v KKR    Wankhede
# 982   105*   63  11  5  166.66   1   not out    2          v CSK    Wankhede
# 1005   76*   45   4  6  168.88   2   not out    2          v CSK    Wankhede
#
#        Start Date     match_id
# 1     14 Nov 2013  Test # 2102
# 9     14 Feb 2014  Test # 2120
# 33    22 Sep 2016  Test # 2221
# 36     8 Oct 2016  Test # 2223
# 38    24 Nov 2017  Test # 2283
# ...           ...          ...
# 827   28 Apr 2018     Twenty20
# 829    4 May 2018     Twenty20
# 862    5 May 2019     Twenty20
# 982   14 Apr 2024     Twenty20
# 1005  20 Apr 2025     Twenty20
#
# [99 rows x 12 columns]

# %%
scores["Runs"].str[0:-1]
# Out:
# 0        17
# 1       111
# 2         1
# 3
# 4
#        ...
# 1009
# 1010
# 1011      2
# 1012      8
# 1013
# Name: Runs, Length: 831, dtype: object

# %%
remove_astx = lambda x: x[:-1] if x.endswith("*") else x

# %%
scores.loc[:,'Runs'] = scores['Runs'].apply(remove_astx)
scores
# Out:
#      Runs   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0     177  301  23  1   58.80   6       lbw    2   v West Indies
# 1     111  127  11  3   87.40   6   not out    2   v West Indies
# 2      14   42   1  0   33.33   5    caught    1  v South Africa
# 3       6   13   1  0   46.15   5    bowled    3  v South Africa
# 4       0    1   0  0    0.00   5    bowled    1  v South Africa
# ...   ...  ...  .. ..     ...  ..       ...  ...             ...
# 1009    7    8   1  0   87.50   2    caught    1            v GT
# 1010    5    5   1  0  100.00   2    caught    1            v DC
# 1011   24   21   2  1  114.28   2    caught    1  v Punjab Kings
# 1012   81   50   9  4  162.00   1    caught    1            v GT
# 1013    8    7   1  0  114.28   1    caught    1  v Punjab Kings
#
#               Ground   Start Date     match_id
# 0       Eden Gardens   6 Nov 2013  Test # 2101
# 1           Wankhede  14 Nov 2013  Test # 2102
# 2       Johannesburg  18 Dec 2013  Test # 2108
# 3       Johannesburg  18 Dec 2013  Test # 2108
# 4             Durban  26 Dec 2013  Test # 2111
# ...              ...          ...          ...
# 1009        Wankhede   6 May 2025     Twenty20
# 1010        Wankhede  21 May 2025     Twenty20
# 1011          Jaipur  26 May 2025     Twenty20
# 1012  New Chandigarh  30 May 2025     Twenty20
# 1013       Ahmedabad   1 Jun 2025     Twenty20
#
# [831 rows x 12 columns]

# %% [markdown]
# #### Identifying '-' in the dataframe and replacing the values

# %%
scores.apply(lambda col: col.astype(str).eq("-").sum())
# Out:
# Runs          0
# BF            0
# 4s            0
# 6s            0
# SR            2
# Pos           0
# Dismissal     0
# Inns          0
# Opposition    0
# Ground        0
# Start Date    0
# match_id      0
# dtype: int64

# %%
scores[scores["SR"]=='-']
# Out:
#     Runs BF 4s 6s SR Pos Dismissal Inns  Opposition    Ground   Start Date  \
# 410    0  0  0  0  -   5   not out    2  v Zimbabwe    Harare  13 Jun 2010
# 645    0  0  0  0  -   3   run out    2       v KKR  Wankhede  25 May 2011
#
#        match_id
# 410  T20I # 183
# 645    Twenty20

# %%
scores.loc[:, "SR"] = scores["SR"].replace("-", 0)

# %% [markdown]
# #### Checking for other nulls

# %%
scores.isna().sum()
# Out:
# Runs          0
# BF            0
# 4s            0
# 6s            0
# SR            0
# Pos           0
# Dismissal     0
# Inns          0
# Opposition    0
# Ground        0
# Start Date    0
# match_id      0
# dtype: int64

# %% [markdown]
# #### Changing datatypes of remaining columns

# %%
scores.dtypes
# Out:
# Runs          object
# BF            object
# 4s            object
# 6s            object
# SR            object
# Pos           object
# Dismissal     object
# Inns          object
# Opposition    object
# Ground        object
# Start Date    object
# match_id      object
# dtype: object

# %%
convert_dict = {
    "Runs":"int",
    "4s":"int",
    "6s":"int",
    "SR":"float",
    "Pos":"int",
    "Inns":"int",
}

# %%
scores = scores.astype(convert_dict,copy=True)

# %%
scores["Start Date"] = pd.to_datetime(scores["Start Date"], format="""%d %b %Y""")

# %%
scores
# Out:
#       Runs   BF  4s  6s      SR  Pos Dismissal  Inns      Opposition  \
# 0      177  301  23   1   58.80    6       lbw     2   v West Indies
# 1      111  127  11   3   87.40    6   not out     2   v West Indies
# 2       14   42   1   0   33.33    5    caught     1  v South Africa
# 3        6   13   1   0   46.15    5    bowled     3  v South Africa
# 4        0    1   0   0    0.00    5    bowled     1  v South Africa
# ...    ...  ...  ..  ..     ...  ...       ...   ...             ...
# 1009     7    8   1   0   87.50    2    caught     1            v GT
# 1010     5    5   1   0  100.00    2    caught     1            v DC
# 1011    24   21   2   1  114.28    2    caught     1  v Punjab Kings
# 1012    81   50   9   4  162.00    1    caught     1            v GT
# 1013     8    7   1   0  114.28    1    caught     1  v Punjab Kings
#
#               Ground Start Date     match_id
# 0       Eden Gardens 2013-11-06  Test # 2101
# 1           Wankhede 2013-11-14  Test # 2102
# 2       Johannesburg 2013-12-18  Test # 2108
# 3       Johannesburg 2013-12-18  Test # 2108
# 4             Durban 2013-12-26  Test # 2111
# ...              ...        ...          ...
# 1009        Wankhede 2025-05-06     Twenty20
# 1010        Wankhede 2025-05-21     Twenty20
# 1011          Jaipur 2025-05-26     Twenty20
# 1012  New Chandigarh 2025-05-30     Twenty20
# 1013       Ahmedabad 2025-06-01     Twenty20
#
# [831 rows x 12 columns]

# %% [markdown]
# #### Removing 'v' from the Opposition table

# %%
scores['Opposition'] = scores['Opposition'].str[2:]

# %%
scores
# Out:
#       Runs   BF  4s  6s      SR  Pos Dismissal  Inns    Opposition  \
# 0      177  301  23   1   58.80    6       lbw     2   West Indies
# 1      111  127  11   3   87.40    6   not out     2   West Indies
# 2       14   42   1   0   33.33    5    caught     1  South Africa
# 3        6   13   1   0   46.15    5    bowled     3  South Africa
# 4        0    1   0   0    0.00    5    bowled     1  South Africa
# ...    ...  ...  ..  ..     ...  ...       ...   ...           ...
# 1009     7    8   1   0   87.50    2    caught     1            GT
# 1010     5    5   1   0  100.00    2    caught     1            DC
# 1011    24   21   2   1  114.28    2    caught     1  Punjab Kings
# 1012    81   50   9   4  162.00    1    caught     1            GT
# 1013     8    7   1   0  114.28    1    caught     1  Punjab Kings
#
#               Ground Start Date     match_id
# 0       Eden Gardens 2013-11-06  Test # 2101
# 1           Wankhede 2013-11-14  Test # 2102
# 2       Johannesburg 2013-12-18  Test # 2108
# 3       Johannesburg 2013-12-18  Test # 2108
# 4             Durban 2013-12-26  Test # 2111
# ...              ...        ...          ...
# 1009        Wankhede 2025-05-06     Twenty20
# 1010        Wankhede 2025-05-21     Twenty20
# 1011          Jaipur 2025-05-26     Twenty20
# 1012  New Chandigarh 2025-05-30     Twenty20
# 1013       Ahmedabad 2025-06-01     Twenty20
#
# [831 rows x 12 columns]

# %% [markdown]
# #### Rename columns

# %%
renamed_cols = {
    "Runs": "runs",
    "BF": "balls_faced",
    "4s": "fours",
    "6s": "sixes",
    "SR": "strike_rate",
    "Pos": "position_batted",
    "Dismissal": "dismissal_type",
    "Inns": "inning",
    "Opposition": "opposition",
    "Ground": "venue",
    "Start Date": "date",
}

# %%
scores = scores.rename(renamed_cols, axis=1, copy=True)

# %%
scores
# Out:
#       runs balls_faced  fours  sixes  strike_rate  position_batted  \
# 0      177         301     23      1        58.80                6
# 1      111         127     11      3        87.40                6
# 2       14          42      1      0        33.33                5
# 3        6          13      1      0        46.15                5
# 4        0           1      0      0         0.00                5
# ...    ...         ...    ...    ...          ...              ...
# 1009     7           8      1      0        87.50                2
# 1010     5           5      1      0       100.00                2
# 1011    24          21      2      1       114.28                2
# 1012    81          50      9      4       162.00                1
# 1013     8           7      1      0       114.28                1
#
#      dismissal_type  inning    opposition           venue       date  \
# 0               lbw       2   West Indies    Eden Gardens 2013-11-06
# 1           not out       2   West Indies        Wankhede 2013-11-14
# 2            caught       1  South Africa    Johannesburg 2013-12-18
# 3            bowled       3  South Africa    Johannesburg 2013-12-18
# 4            bowled       1  South Africa          Durban 2013-12-26
# ...             ...     ...           ...             ...        ...
# 1009         caught       1            GT        Wankhede 2025-05-06
# 1010         caught       1            DC        Wankhede 2025-05-21
# 1011         caught       1  Punjab Kings          Jaipur 2025-05-26
# 1012         caught       1            GT  New Chandigarh 2025-05-30
# 1013         caught       1  Punjab Kings       Ahmedabad 2025-06-01
#
#          match_id
# 0     Test # 2101
# 1     Test # 2102
# 2     Test # 2108
# 3     Test # 2108
# 4     Test # 2111
# ...           ...
# 1009     Twenty20
# 1010     Twenty20
# 1011     Twenty20
# 1012     Twenty20
# 1013     Twenty20
#
# [831 rows x 12 columns]

# %% [markdown]
# ### Merging scores and results table

# %%
test = pd.merge(scores,match_results,on="match_id")

# %%
test
# Out:
#        runs balls_faced  fours  sixes  strike_rate  position_batted  \
# 0       177         301     23      1        58.80                6
# 1       111         127     11      3        87.40                6
# 2        14          42      1      0        33.33                5
# 3         6          13      1      0        46.15                5
# 4         0           1      0      0         0.00                5
# ...     ...         ...    ...    ...          ...              ...
# 91574     8           7      1      0       114.28                1
# 91575     8           7      1      0       114.28                1
# 91576     8           7      1      0       114.28                1
# 91577     8           7      1      0       114.28                1
# 91578     8           7      1      0       114.28                1
#
#       dismissal_type  inning    opposition         venue     date_x  \
# 0                lbw       2   West Indies  Eden Gardens 2013-11-06
# 1            not out       2   West Indies      Wankhede 2013-11-14
# 2             caught       1  South Africa  Johannesburg 2013-12-18
# 3             bowled       3  South Africa  Johannesburg 2013-12-18
# 4             bowled       1  South Africa        Durban 2013-12-26
# ...              ...     ...           ...           ...        ...
# 91574         caught       1  Punjab Kings     Ahmedabad 2025-06-01
# 91575         caught       1  Punjab Kings     Ahmedabad 2025-06-01
# 91576         caught       1  Punjab Kings     Ahmedabad 2025-06-01
# 91577         caught       1  Punjab Kings     Ahmedabad 2025-06-01
# 91578         caught       1  Punjab Kings     Ahmedabad 2025-06-01
#
#           match_id result       date_y
# 0      Test # 2101    won   6 Nov 2013
# 1      Test # 2102    won  14 Nov 2013
# 2      Test # 2108   draw  18 Dec 2013
# 3      Test # 2108   draw  18 Dec 2013
# 4      Test # 2111   lost  26 Dec 2013
# ...            ...    ...          ...
# 91574     Twenty20   lost   6 May 2025
# 91575     Twenty20    won  21 May 2025
# 91576     Twenty20   lost  26 May 2025
# 91577     Twenty20    won  30 May 2025
# 91578     Twenty20   lost   1 Jun 2025
#
# [91579 rows x 14 columns]

# %%
test[test["match_id"] == "Test # 2101"]
# Out:
#    runs balls_faced  fours  sixes  strike_rate  position_batted  \
# 0   177         301     23      1         58.8                6
#
#   dismissal_type  inning   opposition         venue     date_x     match_id  \
# 0            lbw       2  West Indies  Eden Gardens 2013-11-06  Test # 2101
#
#   result      date_y
# 0    won  6 Nov 2013
